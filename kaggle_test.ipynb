# %% [markdown]
# ## 2. Получение предсказаний на тестовой выборке и создание файла для kaggle.

# %% [markdown]
# Считаем данные из яндекс-диска

# %%
import os
import pandas as pd
path = r'C:\Users\Дарья\Desktop\kaggle_data' 
data = {}

Data = []
Target = []

i=0
for dir_entry in sorted(os.listdir(path)):
    dir_entry_path = os.path.join(path, dir_entry)
    if os.path.isfile(dir_entry_path):
        i+=1
        with open(dir_entry_path, 'r') as my_file:
            print(dir_entry_path.split("\\")[-1])
            try:
                df = pd.read_csv(my_file, delimiter=';')
                if df.shape[1] == 5:
                    Data.append(df)
                    Target.append(dir_entry_path.split("\\")[-1])
            except UnicodeDecodeError:
                print(dir_entry_path.split("\\")[-1])
                pass

for dir_entry in sorted(os.listdir(path)):
    dir_entry_path = os.path.join(path, dir_entry)
    if os.path.isfile(dir_entry_path):
        i+=1
        with open(dir_entry_path, 'r') as my_file:
            print(dir_entry_path.split("\\")[-1])
            try:
                df = pd.read_csv(my_file, delimiter=',')
                if df.shape[1] == 5:
                    Data.append(df)
                    Target.append(dir_entry_path.split("\\")[-1])
            except UnicodeDecodeError:
                print(dir_entry_path.split("\\")[-1])
                pass
# Out:
# track_0.csv
# track_1.csv
# track_10.csv
# track_100.csv
# track_101.csv
# track_102.csv
# track_103.csv
# track_104.csv
# track_105.csv
# track_106.csv
# track_107.csv
# track_108.csv
# track_109.csv
# track_11.csv
# track_110.csv
# track_111.csv
# track_112.csv
# track_113.csv
# track_114.csv
# track_115.csv
# track_116.csv
# track_117.csv
# track_118.csv
# track_119.csv
# track_12.csv
# track_120.csv
# track_121.csv
# track_122.csv
# track_123.csv
# track_124.csv
# track_125.csv
# track_126.csv
# track_127.csv
# track_128.csv
# track_129.csv
# track_13.csv
# track_130.csv
# track_131.csv
# track_132.csv
# track_133.csv
# track_134.csv
# track_135.csv
# track_136.csv
# track_137.csv
# track_138.csv
# track_139.csv
# track_14.csv
# track_140.csv
# track_141.csv
# track_142.csv
# track_143.csv
# track_144.csv
# track_145.csv
# track_15.csv
# track_16.csv
# track_17.csv
# track_18.csv
# track_19.csv
# track_2.csv
# track_20.csv
# track_21.csv
# track_22.csv
# track_23.csv
# track_24.csv
# track_25.csv
# track_26.csv
# track_27.csv
# track_28.csv
# track_29.csv
# track_3.csv
# track_30.csv
# track_31.csv
# track_32.csv
# track_33.csv
# track_34.csv
# track_35.csv
# track_36.csv
# track_37.csv
# track_38.csv
# track_39.csv
# track_4.csv
# track_40.csv
# track_41.csv
# track_42.csv
# track_43.csv
# track_44.csv
# track_45.csv
# track_46.csv
# track_47.csv
# track_48.csv
# track_49.csv
# track_5.csv
# track_50.csv
# track_51.csv
# track_52.csv
# track_53.csv
# track_54.csv
# track_55.csv
# track_56.csv
# track_57.csv
# track_58.csv
# track_59.csv
# track_6.csv
# track_60.csv
# track_61.csv
# track_62.csv
# track_63.csv
# track_64.csv
# track_65.csv
# track_66.csv
# track_67.csv
# track_68.csv
# track_69.csv
# track_7.csv
           'втомо' : 5, 'ашин' : 5, 'метро' : 6, 'лектро' : 7, 'амок' : 8}

answers = {'стояние' : 0, 'ходьба' : 1, 'бег' : 2, 'велосипед' : 3, 'лестница' : 4, 
           'автомобиль' : 5, 'метро' : 6, 'электросамокат' : 7, 'самокат' : 8}

# стояние, ходьба, велосипед, лестница, бег, подъем, подъём, автомобиль, электросамокат, машина, метро

# %%
def get_action(name):
    for act in classes:
        if name.lower().find(act) != -1:
            return classes[act]
    return -1

# %% [markdown]
# Обработаем данные и извлечём признаки для создания модели

# %%
import pandas as pd
from matplotlib import pylab as plt
# %pylab inline

def process_data(df, comma=True, cut=True, name = "", a=-1, b=-1):
    
# обрезаем начало и конец трека
    if a == -1:
        st = 1250
    else:
        st = a
            
    if b == -1:
        end = -1250
    else:
        end = b
        
    if cut == False:
        st = 0
        end = -1

    print(name)
#     fig, ((ax1, ax2)) = plt.subplots(nrows=1, ncols=2, figsize=(15,6))

# приводим данные с Iphone к нужному формату
    if comma is True:
        df = df.applymap(lambda x: str(x).replace(',','.'))
        
        try:
            df['gFx'] = df['gFx'].astype(float)
            df['gFy'] = df['gFy'].astype(float)
            df['gFz'] = df['gFz'].astype(float)
        except KeyError:
            return -1

# рисуем графики ускорений
#     if cut:
#         ax1.plot(df.iloc[st:end]['gFx'],c='g')
#         ax1.plot(df.iloc[st:end]['gFy'],c='r')
#         ax1.plot(df.iloc[st:end]['gFz'],c='b')
#     else:
#         ax1.plot(df['gFx'],c='g')
#         ax1.plot(df['gFy'],c='r')
#         ax1.plot(df['gFz'],c='b')
        
# вычисляем модуль (норму) ускорения и рисуем его
    Acc = (df.gFx[st:end] ** 2 + df.gFy[st:end] ** 2 + df.gFz[st:end] ** 2) ** 0.5
#     ax2.plot(Acc)
#     plt.show()

# можно различить многие действия по амплитуде ускорения
    amplitude = Acc.max() - Acc.min()
    print(' АМПЛИТУДА:', Acc.max()-Acc.min())
    print()
    
    return amplitude

Ampl = np.zeros(len(Data)) 

for df, target in zip(Data,Target):
    track_num = int(target.split('_')[1].split('.')[0]) # важный момент, что треки не по нумерации идут!
    Ampl[track_num] = process_data(df, name=target)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# track_0.csv
#  АМПЛИТУДА: 1.2409331302405158
#
# track_1.csv
#  АМПЛИТУДА: 1.9935598883036225
#
# track_10.csv
#  АМПЛИТУДА: 7.802304392990605
#
# track_100.csv
#  АМПЛИТУДА: 0.34113272676839523
#
# track_101.csv
# C:\anaconda\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
#  АМПЛИТУДА: 0.4539765748076482
#
# track_102.csv
#  АМПЛИТУДА: 2.2110203625988167
#
# track_103.csv
#  АМПЛИТУДА: 3.1345378975461413
#
# track_104.csv
#  АМПЛИТУДА: 1.5750179236901385
#
# track_105.csv
#  АМПЛИТУДА: 2.5835429119223496
#
# track_106.csv
#  АМПЛИТУДА: 0.6312015938792386
#
# track_107.csv
#  АМПЛИТУДА: 2.124336238883378
#
# track_108.csv
#  АМПЛИТУДА: 3.1243961620554765
#
# track_109.csv
#  АМПЛИТУДА: nan
#
# track_11.csv
#  АМПЛИТУДА: 1.4499291676896982
#
# track_110.csv
#  АМПЛИТУДА: 1.8330376632404348
#
# track_111.csv
#  АМПЛИТУДА: 0.042436878839561376
#
# track_112.csv
#  АМПЛИТУДА: 1.4825475120699383
#
# track_113.csv
#  АМПЛИТУДА: 0.7902169184700258
#
# track_114.csv
#  АМПЛИТУДА: 0.8574945808044203
#
# track_115.csv
#  АМПЛИТУДА: 5.0103722896175285
#
# track_116.csv
#  АМПЛИТУДА: 2.933115416840867
#
# track_117.csv
#  АМПЛИТУДА: 1.938560304416
#
# track_118.csv
#  АМПЛИТУДА: 1.8007366176688933
#
# track_119.csv
#  АМПЛИТУДА: 2.1336461804594
#
# track_12.csv
#  АМПЛИТУДА: 4.167746272622169
#
# track_120.csv
#  АМПЛИТУДА: 9.491298391484909
#
# track_121.csv
#  АМПЛИТУДА: 0.04905596110186816
#
# track_122.csv
#  АМПЛИТУДА: 6.307166487621298
#
# track_123.csv
#  АМПЛИТУДА: 3.7050364626718366
#
# track_124.csv
#  АМПЛИТУДА: 2.2716957817171166
#
# track_125.csv
#  АМПЛИТУДА: 0.7275186565098009
#
# track_126.csv
#  АМПЛИТУДА: 2.2541200835418818
#
# track_127.csv
#  АМПЛИТУДА: 0.045646484691718836
#
# track_128.csv
#  АМПЛИТУДА: 3.9123474420824778
#
# track_129.csv
#  АМПЛИТУДА: 0.05083922219291459
#
# track_13.csv
#  АМПЛИТУДА: 9.793314652916319
#
# track_130.csv
#  АМПЛИТУДА: 2.84471874204167
#
# track_131.csv
#  АМПЛИТУДА: 2.261836569523423
#
# track_132.csv
#  АМПЛИТУДА: 0.7275186565098009
#
# track_133.csv
#  АМПЛИТУДА: nan
#
# track_134.csv
#  АМПЛИТУДА: 8.086314669791548
#
# track_135.csv
#  АМПЛИТУДА: 5.687705532588813
#
# track_136.csv
#  АМПЛИТУДА: 3.206988566855495
#
# track_137.csv
#  АМПЛИТУДА: 3.228322334766254
#
# track_138.csv
#  АМПЛИТУДА: 0.20033626632139567
#
# track_139.csv
#  АМПЛИТУДА: 0.099461982447971
#
# track_14.csv
#  АМПЛИТУДА: 2.4185341114208763
#
# track_140.csv
#  АМПЛИТУДА: 11.21085698475714
#
# track_141.csv
#  АМПЛИТУДА: 0.01260322791062718
#
# track_142.csv
#  АМПЛИТУДА: 3.304242898758394
#
# track_143.csv
#  АМПЛИТУДА: 0.4194272222654043
#
# track_144.csv
#  АМПЛИТУДА: 2.493435844215357
#
# track_145.csv
#  АМПЛИТУДА: 11.667108550417067
#
# track_15.csv
#  АМПЛИТУДА: 0.9585710148889119
#
# track_16.csv
#  АМПЛИТУДА: 3.546236822015291
#
# track_17.csv
#  АМПЛИТУДА: 3.0087221132495734
#
# track_18.csv
#  АМПЛИТУДА: 0.961968672118849
#
# track_19.csv
#  АМПЛИТУДА: 3.3624614701244164
#
# track_2.csv
#  АМПЛИТУДА: 1.854852429103988
#
# track_20.csv
#  АМПЛИТУДА: 5.444958679602382
#
# track_21.csv
#  АМПЛИТУДА: 3.468369477393101
#
# track_22.csv
#  АМПЛИТУДА: 3.9016035408785554
#
# track_23.csv
#  АМПЛИТУДА: 0.011166805133891233
#
# track_24.csv
#  АМПЛИТУДА: 7.128479662827425
#
# track_25.csv
#  АМПЛИТУДА: 0.1623116441104504
#
# track_26.csv
#  АМПЛИТУДА: 0.741920211510277
#
# track_27.csv
#  АМПЛИТУДА: 2.0100313391555695
#
# track_28.csv
#  АМПЛИТУДА: 3.2323211416069624
#
# track_29.csv
#  АМПЛИТУДА: 2.76747032033991
#
# track_3.csv
#  АМПЛИТУДА: 7.376276708180853
#
# track_30.csv
#  АМПЛИТУДА: 0.1267000078041125
#
# track_31.csv
#  АМПЛИТУДА: 2.731441542408507
#
# track_32.csv
#  АМПЛИТУДА: 1.037319895576775
#
# track_33.csv
#  АМПЛИТУДА: 2.619205131477962
#
# track_34.csv
#  АМПЛИТУДА: 0.2729725656202939
#
# track_35.csv
#  АМПЛИТУДА: nan
#
# track_36.csv
#  АМПЛИТУДА: 0.016567989331872535
#
# track_37.csv
#  АМПЛИТУДА: 0.5447078249883448
#
# track_38.csv
#  АМПЛИТУДА: 0.23734383025525774
#
# track_39.csv
#  АМПЛИТУДА: 0.028022233612311265
#
# track_4.csv
#  АМПЛИТУДА: 2.6161380237808616
#
# track_40.csv
#  АМПЛИТУДА: 6.373970126289841
#
# track_41.csv
#  АМПЛИТУДА: 5.872802467644566
#
# track_42.csv
#  АМПЛИТУДА: 0.11001130326326514
#
# track_43.csv
#  АМПЛИТУДА: 1.1369080200726793
#
# track_44.csv
#  АМПЛИТУДА: 1.5117563691489093
#
# track_45.csv
#  АМПЛИТУДА: 0.011166805133891233
#
# track_46.csv
#  АМПЛИТУДА: 0.24352048452468167
#
# track_47.csv
#  АМПЛИТУДА: 1.5829736314222569
#
# track_48.csv
#  АМПЛИТУДА: 1.615819278458014
#
# track_49.csv
#  АМПЛИТУДА: 3.7617486935148166
#
# track_5.csv
#  АМПЛИТУДА: 2.9399536075474773
#
# track_50.csv
#  АМПЛИТУДА: 1.4499291676896982
#
# track_51.csv
#  АМПЛИТУДА: 7.918585692114179
#
# track_52.csv
#  АМПЛИТУДА: nan
#
# track_53.csv
#  АМПЛИТУДА: 0.2042013068877475
#
# track_54.csv
#  АМПЛИТУДА: 0.8474686147631476
#
# track_55.csv
#  АМПЛИТУДА: 8.830140717365287
#
# track_56.csv
#  АМПЛИТУДА: 9.293501190500901
#
# track_57.csv
#  АМПЛИТУДА: 2.0522956446526943
#
# track_58.csv
#  АМПЛИТУДА: 1.137001353634465
#
# track_59.csv
#  АМПЛИТУДА: 0.07222220171183191
#
# track_6.csv
#  АМПЛИТУДА: 1.5117563691489093
#
# track_60.csv
#  АМПЛИТУДА: 0.5443440449710197
#
# track_61.csv
#  АМПЛИТУДА: 1.3694113030743247
#
# track_62.csv
#  АМПЛИТУДА: 1.4590536437339763
#
# track_63.csv
#  АМПЛИТУДА: 5.762381882202736
#
# track_64.csv
#  АМПЛИТУДА: 0.05703627947763146
#
# track_65.csv
#  АМПЛИТУДА: 1.3694113030743247
#
# track_66.csv
#  АМПЛИТУДА: nan
#
# track_67.csv
#  АМПЛИТУДА: 2.124336238883378
#
# track_68.csv
#  АМПЛИТУДА: 2.407250674120206
#
# track_69.csv
#  АМПЛИТУДА: 1.212572525596172
#
# track_7.csv
#  АМПЛИТУДА: 9.43369600102802
#
# track_70.csv
#  АМПЛИТУДА: 0.06644780954833251
#
# track_71.csv
#  АМПЛИТУДА: 0.5116359327501921
#
# track_72.csv
#  АМПЛИТУДА: 4.351635719111044
#
# track_73.csv
#  АМПЛИТУДА: 2.1336461804594
#
# track_74.csv
#  АМПЛИТУДА: 3.301098397972242
#
# track_75.csv
#  АМПЛИТУДА: 7.158302893444175
#
# track_76.csv
#  АМПЛИТУДА: 9.216037535513616
#
# track_77.csv
#  АМПЛИТУДА: 1.8330376632404348
#
# track_78.csv
#  АМПЛИТУДА: 2.76747032033991
#
# track_79.csv
#  АМПЛИТУДА: 10.731937096693194
#
# track_8.csv
#  АМПЛИТУДА: 0.9393878301836882
#
# track_80.csv
#  АМПЛИТУДА: 1.633777351071156
#
# track_81.csv
#  АМПЛИТУДА: 1.7316058352812163
#
# track_82.csv
#  АМПЛИТУДА: 1.1505238336426609
#
# track_83.csv
#  АМПЛИТУДА: 2.0522956446526943
#
# track_84.csv
#  АМПЛИТУДА: 1.5829736314222569
#
# track_85.csv
#  АМПЛИТУДА: 10.366406365305139
#
# track_86.csv
#  АМПЛИТУДА: 6.151439856806816
#
# track_87.csv
#  АМПЛИТУДА: 2.288305098772688
#
# track_88.csv
#  АМПЛИТУДА: 4.103372254867931
#
# track_89.csv
#  АМПЛИТУДА: 7.956676829256679
#
# track_9.csv
#  АМПЛИТУДА: 0.0754719928206189
#
# track_90.csv
#  АМПЛИТУДА: 0.025694414883784766
#
# track_91.csv
#  АМПЛИТУДА: nan
#
# track_92.csv
#  АМПЛИТУДА: 0.3402407681738169
#
# track_93.csv
#  АМПЛИТУДА: 1.0520805860431857
#
# track_94.csv
#  АМПЛИТУДА: 1.7141168789189019
#
# track_95.csv
#  АМПЛИТУДА: 2.4909275186310906
#
# track_96.csv
#  АМПЛИТУДА: 7.956676829256679
#
# track_97.csv
#  АМПЛИТУДА: 3.0087221132495734
#
# track_98.csv
#  АМПЛИТУДА: 0.3832853345388927
#
# track_99.csv
#  АМПЛИТУДА: 1.4788910252921896

# %% [markdown]
# Напишем функцию для получения предсказания (здесь используется только амплитуда, но в вашем итоговом решении будет больше признаков)

# %%
def rotation_matrix_from_vectors(vec1, vec2):
    """ Find the rotation matrix that aligns vec1 to vec2
    :param vec1: A 3d "source" vector
    :param vec2: A 3d "destination" vector
    :return mat: A transform matrix (3x3) which when applied to vec1, aligns it with vec2.
    """
    a, b = (vec1 / numpy.linalg.norm(vec1)).reshape(3), (vec2 / numpy.linalg.norm(vec2)).reshape(3)
    v = numpy.cross(a, b)
    if any(v): #if not all zeros then 
        c = numpy.dot(a, b)
        s = numpy.linalg.norm(v)
        kmat = numpy.array([[0, -v[2], v[1]], [v[2], 0, -v[0]], [-v[1], v[0], 0]])
        return numpy.eye(3) + kmat + kmat.dot(kmat) * ((1 - c) / (s ** 2))

    else:
        return numpy.eye(3) #cross of all zeros only occurs on identical directions

# %%
def rotate(X, Y, Z, Mat):
    new_x = []
    new_y = []
    new_z = []
    
    for elem in zip(X,Y,Z):
        res = Mat.dot(elem)
        new_x.append(res[0])
        new_y.append(res[1])
        new_z.append(res[2])
        
    return new_x, new_y, new_z

# %%
def integrate(lst):
    res = []
    s = 0
    for elem in lst:
        s += elem
        res.append(s)
    return res

# %%
import pandas as pd
from matplotlib import pylab as plt
# %pylab inline

def process_data1(df, comma=True, cut=True, name = "", a=-1, b=-1):
    if a == -1:
        st = 1250
    else:
        st = a
            
    if b == -1:
        end = -1250
    else:
        end = b
        
    if cut == False:
        st = 0
        end = -1
    df = df.applymap(lambda x: str(x).replace(',','.'))
    df['gFx'] = df['gFx'].astype(float)
    df['gFy'] = df['gFy'].astype(float)
    df['gFz'] = df['gFz'].astype(float)

    Fs = 250 #частота сбора данных

    
    Min = 0

   

    Acc = (df.gFx[st:end] ** 2 + df.gFy[st:end] ** 2 + df.gFz[st:end] ** 2) ** 0.5

    y = Acc.values
    n = len(y) # length of the signal
    if n == 0:
        return (name, 0, 0)
    k = np.arange(n)
    T = n/Fs
    frq = k/T # two sides frequency range
    frq = frq[:len(frq)//2] # one side frequency range

    Y = np.fft.fft(y)/n # dft and normalization
    Y = Y[:n//2]
    
    yabs = abs(Y)
    
    y_max = 0
    x_max = 0
    y_min = 10000
    for i in range(len(yabs)):
        x = frq[i]
        y = yabs[i]
        if 0 <= x and x <= 10 and 0 <= y and y <= 0.5 and y >= y_max:
            x_max = x
            y_max = y
        if 0 <= x and x <= 10 and 0 <= y and y <= 0.5 and y <= y_min:
            y_min = y
    
########################################################################        
    #вычисляем средний вектор ускорения по треку

    mx = df.iloc[st:end]['gFx'].values.mean() 
    my = df.iloc[st:end]['gFy'].values.mean() 
    mz = df.iloc[st:end]['gFz'].values.mean() 
    
#находим матрицу поворота этого вектора к вектору (0,0,1)

    Vec = [mx,my,mz]
    Point = [0, 0, 1]
    mat = rotation_matrix_from_vectors(Vec, Point)
    
#каждую точку трека поворачиваем на эту матрицу

    new_x, new_y, new_z = rotate(df.iloc[st:end]['gFx'].values, df.iloc[st:end]['gFy'].values, df.iloc[st:end]['gFz'].values, mat)

#проверяем, что новые средние равны примерно (0,0,1). Если это не так, значит, телефон часто поворачивался при движении, и нам не поможет это преобразование

#делим на 250*250 (это нужно было еще при интегрировании)
    new_x = [elem / 62500 for elem in new_x]
    new_y = [elem / 62500 for elem in new_y]
#из ускорения по z вычитаем 1 (g), чтобы убрать влияние силы тяжести и оставить только ускорение по z
    new_z = [(elem-1)/62500 for elem in new_z]
    
#дважды интегрируем ускорение, чтобы получить перемещение вдоль каждой оси
    int_x = integrate(integrate(new_x))
    
    int_y = integrate(integrate(new_y))

    int_z = integrate(integrate(new_z))
    
    
    print('Амплитуда3:', max(int_z) - min(int_z))
    print('Амплитуда2:', (y_max - y_min) * 10000)
    
    return (name, max(int_z) - min(int_z), (y_max - y_min) * 10000)

Ampl2 = []
Ampl3 = []

for df, target in zip(Data,Target):
    answ = process_data1(df, name=target)
    Ampl2.append(answ[2])
    Ampl3.append(answ[1])
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Амплитуда3: 0.07224694754223264
# Амплитуда2: 1230.8468681999138
# Амплитуда3: 62.614527707310124
# Амплитуда2: 758.9249066284618
# Амплитуда3: 0.9457827346098793
# Амплитуда2: 2568.096221205726
# Амплитуда3: 57.053470131057075
# Амплитуда2: 1.0069916032595136
# Амплитуда3: 1.0683705088237152
# Амплитуда2: 66.88809928803317
# Амплитуда3: 9.704615848731528
# Амплитуда2: 1039.7119318675154
# Амплитуда3: 432.02614845163754
# Амплитуда2: 1241.249867042064
# Амплитуда3: 0.003617829068416394
# Амплитуда2: 1284.865100226395
# Амплитуда3: 4.879549285649216
# Амплитуда2: 481.34832868218257
# Амплитуда3: 24.271634875979306
# Амплитуда2: 23.146088784258872
# Амплитуда3: 5.831638804256301
# Амплитуда2: 379.76904938213966
# Амплитуда3: 912.3065937200768
# Амплитуда2: 553.7286843849306
# Амплитуда3: 1.529079537300863
# Амплитуда2: 600.2879739835154
# Амплитуда3: 0.9544114507787035
# Амплитуда2: 567.5685960352005
# Амплитуда3: 17.996954404146354
# Амплитуда2: 3.376832844884951
# Амплитуда3: 0.18122208543146304
# Амплитуда2: 1488.9767194689632
# Амплитуда3: 13.591567418544757
# Амплитуда2: 88.14909260814346
# Амплитуда3: 0.027825126110717042
# Амплитуда2: 713.012075419482
# Амплитуда3: 1.1268232081254193
# Амплитуда2: 1982.876408352812
# Амплитуда3: 0.32110064619766326
# Амплитуда2: 1626.9605481473545
# Амплитуда3: 11.237433010637538
# Амплитуда2: 58.55066636143425
# Амплитуда3: 0.21414457053062033
# Амплитуда2: 381.35276364698404
# Амплитуда3: 3.0553419098974754
# Амплитуда2: 410.88977659440326
# Амплитуда3: 0.09912968941792434
# Амплитуда2: 3642.044131839539
# Амплитуда3: 216.9877212784559
# Амплитуда2: 2689.519812323418
# Амплитуда3: 28.510424835479473
# Амплитуда2: 5.772035392579473
# Амплитуда3: 244.89599573365982
# Амплитуда2: 805.3109930043835
# Амплитуда3: 146.0643916379496
# Амплитуда2: 603.3607169419762
# Амплитуда3: 0.16478914176122836
# Амплитуда2: 1257.930208328945
# Амплитуда3: 0.15915233464327658
# Амплитуда2: 266.7244281012229
# Амплитуда3: 26.04793217874855
# Амплитуда2: 2781.478760629975
# Амплитуда3: 0.05414582087594931
# Амплитуда2: 6.933850017444668
# Амплитуда3: 93.72625054903483
# Амплитуда3: 66.3470038919256
# Амплитуда2: 3313.6300735192413
# Амплитуда3: 0.9544114507787035
# Амплитуда2: 567.5685960352005
# Амплитуда3: 117.4898209599205
# Амплитуда2: 519.2394141823637
# Амплитуда3: 401.69462043615516
# Амплитуда2: 3487.373050885681
# Амплитуда3: 0.03481732094957589
# Амплитуда2: 444.607038559744
# Амплитуда3: 0.01874298507458211
# Амплитуда2: 1270.6056559521269
# Амплитуда3: 104.15734142322002
# Амплитуда2: 231.31298625382837
# Амплитуда3: 0.004141040970639757
# Амплитуда2: 677.6536739892186
# Амплитуда3: 1.2110215594596059
# Амплитуда2: 412.1222436299845
# Амплитуда3: 0.001452948616142243
# Амплитуда2: -100000000
# Амплитуда3: 198.49235698979868
# Амплитуда2: 3804.1257610777197
# Амплитуда3: 112.69594925225547
# Амплитуда2: 654.7401774175557
# Амплитуда3: 1.4513868633187637
# Амплитуда2: 1873.0342067802862
# Амплитуда3: 1.3594431509846439
# Амплитуда2: 2232.293392782207
# Амплитуда3: 1657.2004163389868
# Амплитуда2: 380.35156559287844
# Амплитуда3: 175.21839025756202
# Амплитуда2: 4.184613500575743
# Амплитуда3: 0.05209668583021566
# Амплитуда2: 2.1018342588379846
# Амплитуда3: 26.76001202481389
# Амплитуда2: 14.839033596096616
# Амплитуда3: 0.40977050062910153
# Амплитуда2: 679.4932340023294
# Амплитуда3: 69.62295177820056
# Амплитуда2: 24.514237134235234
# Амплитуда3: 0.12971574756483126
# Амплитуда2: 781.3335286762285
# Амплитуда3: 1657.2004163389868
# Амплитуда2: 380.35156559287844
# Амплитуда3: 1259.7017591134017
# Амплитуда2: 278.79939287348355
# Амплитуда3: 8.931837794503913
# Амплитуда2: 8.595331596145638
# Амплитуда3: 83.78515036672628
# Амплитуда2: 505.5800760111556

# %%
def get_prediction(ampl, ampl2, ampl3):
    if ampl < 1:
        return 0 #стояние
    if ampl >  5:
        return 2 #бег
    if ampl2 < 500:
        print(3)
        return 3 #велосипед
    if ampl3 > 100:
        return 4
    return 1 #ходьба

# %%
len(Data), len(Ampl), len(Target), len(Ampl2), len(Ampl3)
# Out:
# (146, 146, 146, 146, 146)

# %%
type(Data)
# Out:
# list

# %%
Ampl_new = []

i=0
for elem in Ampl:
    if not (math.isnan(elem) or elem == -1):
        i+=1
        Ampl_new.append(elem)
    else:
        Ampl_new.append(2)
len(Ampl_new), i
# Out:
# (146, 140)

# %%
Neww = [[Ampl[i], Ampl2[i], Ampl3[i]] for i in range(146)]

# %% [markdown]
# Создадим таблицу, содержащую номер трека и предсказание.

# %%
prediction = [get_prediction(a[0], a[1], a[2]) for a in Neww]

Res = pd.DataFrame({'track_num' : np.arange(len(Data)), 'action' : prediction})
Res.head(10)
# Out:
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
#    track_num  action
# 0          0       1
# 1          1       1
# 2          2       1
# 3          3       2
# 4          4       3
# 5          5       1
# 6          6       4
# 7          7       2
# 8          8       0
# 9          9       0

# %%
Res.to_csv("Nabatova_Darya_4.csv", index=False)
